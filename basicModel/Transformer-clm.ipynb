# %% [markdown]
# # Session-based Recs with Transformers4Rec: Transformer - Causal Language Model
#
# Followed a step by step tutorial:
# https://nvidia-merlin.github.io/Transformers4Rec/main/examples/tutorial/index.html

# %% [markdown]
# ## Imports

# %%
import os
import glob
import pandas as pd
import numpy as np

from transformers4rec import tf as tr
import tensorflow as tf
from transformers4rec.tf.ranking_metric import NDCGAt, RecallAt
from typing import Optional

# %% [markdown]
# ## Instantiates Schema object from schema file

# %%
# define the input file path
INPUT_DATA_DIR = os.environ.get("INPUT_DATA_DIR", '../data/')
# define the output file path
OUTPUT_DIR = os.environ.get("OUTPUT_DIR", "../data/sessions_by_day")
# features chosen to train on
chosen_features = ['product_id-list_seq']
from merlin_standard_lib import Schema
# define schema object to pass it to the TabularSeqeunceFeatures class
SCHEMA_PATH = os.path.join(INPUT_DATA_DIR, 'schema.pb')
schema = Schema().from_proto_text(SCHEMA_PATH)
schema = schema.select_by_name(chosen_features)

# %% [markdown]
# ## Define Input Block

# %% [markdown]
# use MLM as the training method

# %%
# Input
sequence_length, d_model = 20, 192
# Define input module to process tabular input-features and to prepare masked inputs
inputs = tr.TabularSequenceFeatures.from_schema(
    schema,
    max_sequence_length = sequence_length,
    d_output = d_model,
    masking = 'clm'
)

# %% [markdown]
# ## Build Transformer Block

# %%
# define XLNetConfig class and set default parameters for HF XLNet config
transformer_config = tr.XLNetConfig.build(
    d_model = d_model, n_head=4, n_layer=2, total_seq_length=sequence_length
)

# define the model block including: inputs, masking, projection and transformer block.

body = tr.SequentialBlock(
    [inputs,
    tr.MLPBlock([192]),
    tr.TransformerBlock(transformer_config, masking=inputs.masking)]
)

# define the head for to the next item prediction task

head = tr.Head(
    body,
    tr.NextItemPredictionTask(
        weight_tying=True, 
        # hf_format=True, 
        metrics=[NDCGAt(top_ks=[10, 20], labels_onehot=True),RecallAt(top_ks=[10, 20], labels_onehot=True)],
        # loss = tf.keras.losses.CategoricalCrossentropy)
))
# head = tr.Head(
#     body,
#     tr.NextItemPredictionTask(
#         weight_tying=True, 
#         # hf_format=True, 
#         metrics=[NDCGAt_temp(top_ks=[10, 20], labels_onehot=False)]
#         # loss = tf.keras.losses.CategoricalCrossentropy)
# ))

# get the end-to-end Model class

model = tr.Model(head)

# %% [markdown]
# ## Build Datasets

# %%
def iterate_over_df(
    ### iterator function as input for the tensorflow generator `from_generator` function
    df: pd.DataFrame
):  
    df['empty_list'] = [[] for _ in range(len(df))]
    def caller():
        for _,j in df.iterrows():
            yield(j['product_id-list_seq']),j['empty_list']
    return caller

# %%
def ds_from_df(
    ### generate tensorflow object from dataframe
    df: pd.DataFrame
):
    output_shape_x = (
        tf.TensorShape([None,])
    )
    df = tf.data.Dataset.from_generator(
        iterate_over_df(df),
        output_types=((tf.int32),tf.int32),
        output_shapes = (output_shape_x, tf.TensorShape([None,]))
    )
    return df

# %%
def pad_dataset(
        ## pad dataset so all session sequence data have length 20
        df,
        batch_size: int,
):
        df = df.shuffle(5)
        df = df.padded_batch(batch_size, padded_shapes = (([20,]),[0,]), padding_values = ((0),0),drop_remainder=True)
        df = df.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

        return df

# %%
def data_to_dict(
    ### create a dictionary tensor dataframe as input into the model
    df_list: list,
    chosen_features: list
):
    df_dictionary = {}
    df_dictionary2 = {}
    if len(chosen_features) == 1:
        df_dictionary[chosen_features[0]] = df_list[0][0]
    else:
        for i in range(len(chosen_features)):
            df_dictionary[chosen_features[i]] = df_list[0][0][i]
        df_dictionary2['labels'] = df_list[0][-1]
    return (df_dictionary, df_dictionary2)

# %%
def get_dataset(
    ### function to call all other functions necessary to build the dataset
    ### to input into the model
    df,
    batch_size,
    df_len
):
    df = ds_from_df(df)
    df = pad_dataset(df,df_len)
    df = data_to_dict(list(df),chosen_features)
    ds = tf.data.Dataset.from_tensor_slices(df).batch(batch_size)
    steps = int(np.floor(df_len/batch_size))
    ds = ds.map(lambda X, y: (X, []))


    return ds, steps

# %% [markdown]
# ## Daily Fine-tuning: Training over a time window

# %% [markdown]
# ### Train the model

# %%
model.compile(optimizer='adam',run_eagerly=True)

# %%
train_batch_size = 256
eval_batch_size = 32

# %%
# %%time
# window
start_time_window_index = 1
final_time_window_index = 3
# Iterating over days of one week
for time_index in range(start_time_window_index, final_time_window_index):
    # Set data 
    time_index_train = time_index
    time_index_eval = time_index + 1
    train_paths = os.path.join(OUTPUT_DIR, f"{time_index_train}/train.parquet")
    eval_paths = os.path.join(OUTPUT_DIR, f"{time_index_eval}/valid.parquet")

    # Load data
    train_df = pd.read_parquet(train_paths)
    train_df = train_df[['product_id-list_seq']]
    eval_df = pd.read_parquet(eval_paths)
    eval_df = eval_df[['product_id-list_seq']]

    # find length of dataframes for argument into `get_dataset`
    train_len = len(train_df)
    eval_len = len(eval_df)

    # get datasets
    train_dataset, train_steps = get_dataset(train_df, train_batch_size,train_len)
    eval_dataset, eval_steps = get_dataset(eval_df, eval_batch_size,eval_len)
    
    # Train on day related to time_index 
    print('*'*20)
    print("Launch training for day %s are:" %time_index)
    print('*'*20 + '\n')
    losses = model.fit(train_dataset, epochs=1)
    model.reset_metrics()
    # Evaluate on the following day
    eval_metrics = model.evaluate(eval_dataset, return_dict=True)
    print('*'*20)
    print("Eval results for day %s are:\t" %time_index_eval)
    print('\n' + '*'*20 + '\n')
    for key in sorted(eval_metrics.keys()):
        print(" %s = %s" % (key, str(eval_metrics[key])))
# Out:
# ********************
# Launch training for day 1 are:
# ********************
# Projecting inputs of NextItemPredictionTask to'64' As weight tying requires the input dimension '192' to be equal to the item-id embedding dimension '64'
# WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   1/438 [..............................] - ETA: 1:31:33 - train_ndcg@10: 3.9076e-04 - train_ndcg@20: 3.9076e-04 - train_recall@10: 0.0010 - train_recall@20: 0.0010 - loss: 11.9983 - regularization_loss: 0.0000e+00 - total_loss: 11.9983WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   2/438 [..............................] - ETA: 38:35 - train_ndcg@10: 1.9538e-04 - train_ndcg@20: 1.9538e-04 - train_recall@10: 5.0505e-04 - train_recall@20: 5.0505e-04 - loss: 11.9274 - regularization_loss: 0.0000e+00 - total_loss: 11.9274WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   3/438 [..............................] - ETA: 40:05 - train_ndcg@10: 1.3025e-04 - train_ndcg@20: 2.0652e-04 - train_recall@10: 3.3670e-04 - train_recall@20: 6.2706e-04 - loss: 11.8786 - regularization_loss: 0.0000e+00 - total_loss: 11.8786WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   4/438 [..............................] - ETA: 41:20 - train_ndcg@10: 9.7690e-05 - train_ndcg@20: 1.5489e-04 - train_recall@10: 2.5253e-04 - train_recall@20: 4.7030e-04 - loss: 11.8358 - regularization_loss: 0.0000e+00 - total_loss: 11.8358WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   5/438 [..............................] - ETA: 41:17 - train_ndcg@10: 7.8152e-05 - train_ndcg@20: 1.2391e-04 - train_recall@10: 2.0202e-04 - train_recall@20: 3.7624e-04 - loss: 11.8067 - regularization_loss: 0.0000e+00 - total_loss: 11.8067WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   6/438 [..............................] - ETA: 40:53 - train_ndcg@10: 1.6003e-04 - train_ndcg@20: 1.9816e-04 - train_recall@10: 3.1877e-04 - train_recall@20: 4.6395e-04 - loss: 11.7852 - regularization_loss: 0.0000e+00 - total_loss: 11.7852WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   7/438 [..............................] - ETA: 40:38 - train_ndcg@10: 2.3143e-04 - train_ndcg@20: 3.2476e-04 - train_recall@10: 5.3086e-04 - train_recall@20: 9.1294e-04 - loss: 11.7701 - regularization_loss: 0.0000e+00 - total_loss: 11.7701WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   8/438 [..............................] - ETA: 39:56 - train_ndcg@10: 2.6377e-04 - train_ndcg@20: 4.3816e-04 - train_recall@10: 5.8706e-04 - train_recall@20: 0.0013 - loss: 11.7583 - regularization_loss: 0.0000e+00 - total_loss: 11.7583    WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   9/438 [..............................] - ETA: 40:29 - train_ndcg@10: 4.7027e-04 - train_ndcg@20: 6.4693e-04 - train_recall@10: 9.7313e-04 - train_recall@20: 0.0017 - loss: 11.7488 - regularization_loss: 0.0000e+00 - total_loss: 11.7488WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  10/438 [..............................] - ETA: 40:07 - train_ndcg@10: 4.2325e-04 - train_ndcg@20: 6.2669e-04 - train_recall@10: 8.7582e-04 - train_recall@20: 0.0017 - loss: 11.7415 - regularization_loss: 0.0000e+00 - total_loss: 11.7415WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  11/438 [..............................] - ETA: 40:37 - train_ndcg@10: 3.8477e-04 - train_ndcg@20: 5.6972e-04 - train_recall@10: 7.9620e-04 - train_recall@20: 0.0016 - loss: 11.7355 - regularization_loss: 0.0000e+00 - total_loss: 11.7355WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  12/438 [..............................] - ETA: 40:11 - train_ndcg@10: 3.5271e-04 - train_ndcg@20: 5.2224e-04 - train_recall@10: 7.2985e-04 - train_recall@20: 0.0014 - loss: 11.7302 - regularization_loss: 0.0000e+00 - total_loss: 11.7302WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  13/438 [..............................] - ETA: 40:00 - train_ndcg@10: 3.9519e-04 - train_ndcg@20: 5.7110e-04 - train_recall@10: 7.4332e-04 - train_recall@20: 0.0015 - loss: 11.7256 - regularization_loss: 0.0000e+00 - total_loss: 11.7256WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  14/438 [..............................] - ETA: 40:01 - train_ndcg@10: 5.1471e-04 - train_ndcg@20: 7.0932e-04 - train_recall@10: 9.8784e-04 - train_recall@20: 0.0018 - loss: 11.7217 - regularization_loss: 0.0000e+00 - total_loss: 11.7217WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  15/438 [>.............................] - ETA: 39:40 - train_ndcg@10: 5.2831e-04 - train_ndcg@20: 7.5843e-04 - train_recall@10: 0.0011 - train_recall@20: 0.0020 - loss: 11.7181 - regularization_loss: 0.0000e+00 - total_loss: 11.7181    WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  16/438 [>.............................] - ETA: 39:24 - train_ndcg@10: 5.1332e-04 - train_ndcg@20: 7.2905e-04 - train_recall@10: 0.0010 - train_recall@20: 0.0019 - loss: 11.7145 - regularization_loss: 0.0000e+00 - total_loss: 11.7145WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  17/438 [>.............................] - ETA: 39:20 - train_ndcg@10: 4.9814e-04 - train_ndcg@20: 7.0118e-04 - train_recall@10: 0.0010 - train_recall@20: 0.0018 - loss: 11.7117 - regularization_loss: 0.0000e+00 - total_loss: 11.7117WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  18/438 [>.............................] - ETA: 39:12 - train_ndcg@10: 4.7047e-04 - train_ndcg@20: 6.6223e-04 - train_recall@10: 9.7766e-04 - train_recall@20: 0.0017 - loss: 11.7096 - regularization_loss: 0.0000e+00 - total_loss: 11.7096WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  19/438 [>.............................] - ETA: 39:03 - train_ndcg@10: 4.7909e-04 - train_ndcg@20: 6.6076e-04 - train_recall@10: 0.0010 - train_recall@20: 0.0017 - loss: 11.7070 - regularization_loss: 0.0000e+00 - total_loss: 11.7070    WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  20/438 [>.............................] - ETA: 38:59 - train_ndcg@10: 5.7457e-04 - train_ndcg@20: 7.5880e-04 - train_recall@10: 0.0012 - train_recall@20: 0.0020 - loss: 11.7045 - regularization_loss: 0.0000e+00 - total_loss: 11.7045WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  21/438 [>.............................] - ETA: 39:00 - train_ndcg@10: 6.8026e-04 - train_ndcg@20: 8.7504e-04 - train_recall@10: 0.0015 - train_recall@20: 0.0022 - loss: 11.7025 - regularization_loss: 0.0000e+00 - total_loss: 11.7025WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  22/438 [>.............................] - ETA: 38:47 - train_ndcg@10: 7.5074e-04 - train_ndcg@20: 9.4708e-04 - train_recall@10: 0.0015 - train_recall@20: 0.0023 - loss: 11.7002 - regularization_loss: 0.0000e+00 - total_loss: 11.7002WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  23/438 [>.............................] - ETA: 38:43 - train_ndcg@10: 7.5648e-04 - train_ndcg@20: 9.4429e-04 - train_recall@10: 0.0015 - train_recall@20: 0.0023 - loss: 11.6984 - regularization_loss: 0.0000e+00 - total_loss: 11.6984WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  24/438 [>.............................] - ETA: 38:47 - train_ndcg@10: 8.1889e-04 - train_ndcg@20: 0.0010 - train_recall@10: 0.0016 - train_recall@20: 0.0024 - loss: 11.6971 - regularization_loss: 0.0000e+00 - total_loss: 11.6971    WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  25/438 [>.............................] - ETA: 38:46 - train_ndcg@10: 8.6477e-04 - train_ndcg@20: 0.0011 - train_recall@10: 0.0017 - train_recall@20: 0.0026 - loss: 11.6956 - regularization_loss: 0.0000e+00 - total_loss: 11.6956WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  26/438 [>.............................] - ETA: 38:49 - train_ndcg@10: 0.0010 - train_ndcg@20: 0.0013 - train_recall@10: 0.0019 - train_recall@20: 0.0029 - loss: 11.6937 - regularization_loss: 0.0000e+00 - total_loss: 11.6937    WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  27/438 [>.............................] - ETA: 38:44 - train_ndcg@10: 0.0011 - train_ndcg@20: 0.0014 - train_recall@10: 0.0021 - train_recall@20: 0.0032 - loss: 11.6920 - regularization_loss: 0.0000e+00 - total_loss: 11.6920WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  28/438 [>.............................] - ETA: 38:30 - train_ndcg@10: 0.0011 - train_ndcg@20: 0.0014 - train_recall@10: 0.0021 - train_recall@20: 0.0032 - loss: 11.6903 - regularization_loss: 0.0000e+00 - total_loss: 11.6903WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  29/438 [>.............................] - ETA: 38:32 - train_ndcg@10: 0.0011 - train_ndcg@20: 0.0014 - train_recall@10: 0.0020 - train_recall@20: 0.0031 - loss: 11.6886 - regularization_loss: 0.0000e+00 - total_loss: 11.6886WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  30/438 [=>............................] - ETA: 38:29 - train_ndcg@10: 0.0011 - train_ndcg@20: 0.0013 - train_recall@10: 0.0020 - train_recall@20: 0.0031 - loss: 11.6875 - regularization_loss: 0.0000e+00 - total_loss: 11.6875WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  31/438 [=>............................] - ETA: 38:19 - train_ndcg@10: 0.0010 - train_ndcg@20: 0.0013 - train_recall@10: 0.0019 - train_recall@20: 0.0031 - loss: 11.6861 - regularization_loss: 0.0000e+00 - total_loss: 11.6861WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  32/438 [=>............................] - ETA: 38:10 - train_ndcg@10: 9.9009e-04 - train_ndcg@20: 0.0013 - train_recall@10: 0.0019 - train_recall@20: 0.0030 - loss: 11.6843 - regularization_loss: 0.0000e+00 - total_loss: 11.6843WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  33/438 [=>............................] - ETA: 38:03 - train_ndcg@10: 9.6919e-04 - train_ndcg@20: 0.0013 - train_recall@10: 0.0019 - train_recall@20: 0.0030 - loss: 11.6826 - regularization_loss: 0.0000e+00 - total_loss: 11.6826WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  34/438 [=>............................] - ETA: 38:00 - train_ndcg@10: 9.5172e-04 - train_ndcg@20: 0.0012 - train_recall@10: 0.0018 - train_recall@20: 0.0030 - loss: 11.6815 - regularization_loss: 0.0000e+00 - total_loss: 11.6815WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  35/438 [=>............................] - ETA: 37:50 - train_ndcg@10: 0.0012 - train_ndcg@20: 0.0015 - train_recall@10: 0.0022 - train_recall@20: 0.0034 - loss: 11.6795 - regularization_loss: 0.0000e+00 - total_loss: 11.6795    WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  36/438 [=>............................] - ETA: 37:41 - train_ndcg@10: 0.0013 - train_ndcg@20: 0.0016 - train_recall@10: 0.0025 - train_recall@20: 0.0037 - loss: 11.6781 - regularization_loss: 0.0000e+00 - total_loss: 11.6781WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  37/438 [=>............................] - ETA: 37:40 - train_ndcg@10: 0.0014 - train_ndcg@20: 0.0017 - train_recall@10: 0.0026 - train_recall@20: 0.0039 - loss: 11.6760 - regularization_loss: 0.0000e+00 - total_loss: 11.6760WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  38/438 [=>............................] - ETA: 37:36 - train_ndcg@10: 0.0014 - train_ndcg@20: 0.0017 - train_recall@10: 0.0026 - train_recall@20: 0.0039 - loss: 11.6746 - regularization_loss: 0.0000e+00 - total_loss: 11.6746WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  39/438 [=>............................] - ETA: 37:26 - train_ndcg@10: 0.0014 - train_ndcg@20: 0.0017 - train_recall@10: 0.0026 - train_recall@20: 0.0039 - loss: 11.6732 - regularization_loss: 0.0000e+00 - total_loss: 11.6732WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  40/438 [=>............................] - ETA: 37:13 - train_ndcg@10: 0.0014 - train_ndcg@20: 0.0018 - train_recall@10: 0.0027 - train_recall@20: 0.0040 - loss: 11.6713 - regularization_loss: 0.0000e+00 - total_loss: 11.6713WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  41/438 [=>............................] - ETA: 37:11 - train_ndcg@10: 0.0014 - train_ndcg@20: 0.0018 - train_recall@10: 0.0027 - train_recall@20: 0.0040 - loss: 11.6691 - regularization_loss: 0.0000e+00 - total_loss: 11.6691WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  42/438 [=>............................] - ETA: 37:02 - train_ndcg@10: 0.0015 - train_ndcg@20: 0.0018 - train_recall@10: 0.0027 - train_recall@20: 0.0040 - loss: 11.6667 - regularization_loss: 0.0000e+00 - total_loss: 11.6667WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  43/438 [=>............................] - ETA: 37:01 - train_ndcg@10: 0.0015 - train_ndcg@20: 0.0018 - train_recall@10: 0.0028 - train_recall@20: 0.0041 - loss: 11.6647 - regularization_loss: 0.0000e+00 - total_loss: 11.6647WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  44/438 [==>...........................] - ETA: 36:49 - train_ndcg@10: 0.0015 - train_ndcg@20: 0.0018 - train_recall@10: 0.0028 - train_recall@20: 0.0041 - loss: 11.6624 - regularization_loss: 0.0000e+00 - total_loss: 11.6624WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  45/438 [==>...........................] - ETA: 36:44 - train_ndcg@10: 0.0015 - train_ndcg@20: 0.0018 - train_recall@10: 0.0028 - train_recall@20: 0.0041 - loss: 11.6602 - regularization_loss: 0.0000e+00 - total_loss: 11.6602WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  46/438 [==>...........................] - ETA: 36:37 - train_ndcg@10: 0.0015 - train_ndcg@20: 0.0019 - train_recall@10: 0.0028 - train_recall@20: 0.0041 - loss: 11.6577 - regularization_loss: 0.0000e+00 - total_loss: 11.6577WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  47/438 [==>...........................] - ETA: 36:31 - train_ndcg@10: 0.0017 - train_ndcg@20: 0.0020 - train_recall@10: 0.0030 - train_recall@20: 0.0044 - loss: 11.6555 - regularization_loss: 0.0000e+00 - total_loss: 11.6555WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  48/438 [==>...........................] - ETA: 36:24 - train_ndcg@10: 0.0017 - train_ndcg@20: 0.0020 - train_recall@10: 0.0031 - train_recall@20: 0.0045 - loss: 11.6532 - regularization_loss: 0.0000e+00 - total_loss: 11.6532WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  49/438 [==>...........................] - ETA: 36:21 - train_ndcg@10: 0.0017 - train_ndcg@20: 0.0020 - train_recall@10: 0.0031 - train_recall@20: 0.0045 - loss: 11.6506 - regularization_loss: 0.0000e+00 - total_loss: 11.6506WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  50/438 [==>...........................] - ETA: 36:12 - train_ndcg@10: 0.0017 - train_ndcg@20: 0.0021 - train_recall@10: 0.0032 - train_recall@20: 0.0046 - loss: 11.6477 - regularization_loss: 0.0000e+00 - total_loss: 11.6477WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  51/438 [==>...........................] - ETA: 36:02 - train_ndcg@10: 0.0018 - train_ndcg@20: 0.0022 - train_recall@10: 0.0034 - train_recall@20: 0.0048 - loss: 11.6453 - regularization_loss: 0.0000e+00 - total_loss: 11.6453WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  52/438 [==>...........................] - ETA: 35:52 - train_ndcg@10: 0.0019 - train_ndcg@20: 0.0022 - train_recall@10: 0.0036 - train_recall@20: 0.0050 - loss: 11.6421 - regularization_loss: 0.0000e+00 - total_loss: 11.6421WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  53/438 [==>...........................] - ETA: 35:49 - train_ndcg@10: 0.0019 - train_ndcg@20: 0.0023 - train_recall@10: 0.0038 - train_recall@20: 0.0051 - loss: 11.6393 - regularization_loss: 0.0000e+00 - total_loss: 11.6393WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  54/438 [==>...........................] - ETA: 35:46 - train_ndcg@10: 0.0020 - train_ndcg@20: 0.0024 - train_recall@10: 0.0040 - train_recall@20: 0.0054 - loss: 11.6352 - regularization_loss: 0.0000e+00 - total_loss: 11.6352WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  55/438 [==>...........................] - ETA: 35:41 - train_ndcg@10: 0.0021 - train_ndcg@20: 0.0024 - train_recall@10: 0.0042 - train_recall@20: 0.0055 - loss: 11.6315 - regularization_loss: 0.0000e+00 - total_loss: 11.6315WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  56/438 [==>...........................] - ETA: 35:35 - train_ndcg@10: 0.0021 - train_ndcg@20: 0.0025 - train_recall@10: 0.0043 - train_recall@20: 0.0057 - loss: 11.6268 - regularization_loss: 0.0000e+00 - total_loss: 11.6268WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  57/438 [==>...........................] - ETA: 35:28 - train_ndcg@10: 0.0022 - train_ndcg@20: 0.0025 - train_recall@10: 0.0045 - train_recall@20: 0.0058 - loss: 11.6231 - regularization_loss: 0.0000e+00 - total_loss: 11.6231WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  58/438 [==>...........................] - ETA: 35:19 - train_ndcg@10: 0.0022 - train_ndcg@20: 0.0026 - train_recall@10: 0.0046 - train_recall@20: 0.0059 - loss: 11.6190 - regularization_loss: 0.0000e+00 - total_loss: 11.6190WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  59/438 [===>..........................] - ETA: 35:14 - train_ndcg@10: 0.0024 - train_ndcg@20: 0.0027 - train_recall@10: 0.0048 - train_recall@20: 0.0062 - loss: 11.6136 - regularization_loss: 0.0000e+00 - total_loss: 11.6136WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  60/438 [===>..........................] - ETA: 35:04 - train_ndcg@10: 0.0024 - train_ndcg@20: 0.0028 - train_recall@10: 0.0050 - train_recall@20: 0.0064 - loss: 11.6082 - regularization_loss: 0.0000e+00 - total_loss: 11.6082WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  61/438 [===>..........................] - ETA: 34:57 - train_ndcg@10: 0.0025 - train_ndcg@20: 0.0029 - train_recall@10: 0.0051 - train_recall@20: 0.0065 - loss: 11.6028 - regularization_loss: 0.0000e+00 - total_loss: 11.6028WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  62/438 [===>..........................] - ETA: 34:49 - train_ndcg@10: 0.0026 - train_ndcg@20: 0.0030 - train_recall@10: 0.0053 - train_recall@20: 0.0067 - loss: 11.5959 - regularization_loss: 0.0000e+00 - total_loss: 11.5959WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  63/438 [===>..........................] - ETA: 34:41 - train_ndcg@10: 0.0027 - train_ndcg@20: 0.0031 - train_recall@10: 0.0054 - train_recall@20: 0.0068 - loss: 11.5900 - regularization_loss: 0.0000e+00 - total_loss: 11.5900WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  64/438 [===>..........................] - ETA: 34:35 - train_ndcg@10: 0.0028 - train_ndcg@20: 0.0032 - train_recall@10: 0.0056 - train_recall@20: 0.0069 - loss: 11.5835 - regularization_loss: 0.0000e+00 - total_loss: 11.5835WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  65/438 [===>..........................] - ETA: 34:30 - train_ndcg@10: 0.0029 - train_ndcg@20: 0.0033 - train_recall@10: 0.0057 - train_recall@20: 0.0072 - loss: 11.5759 - regularization_loss: 0.0000e+00 - total_loss: 11.5759WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  66/438 [===>..........................] - ETA: 34:24 - train_ndcg@10: 0.0029 - train_ndcg@20: 0.0033 - train_recall@10: 0.0057 - train_recall@20: 0.0072 - loss: 11.5682 - regularization_loss: 0.0000e+00 - total_loss: 11.5682WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  67/438 [===>..........................] - ETA: 34:20 - train_ndcg@10: 0.0030 - train_ndcg@20: 0.0034 - train_recall@10: 0.0058 - train_recall@20: 0.0074 - loss: 11.5592 - regularization_loss: 0.0000e+00 - total_loss: 11.5592WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  68/438 [===>..........................] - ETA: 34:17 - train_ndcg@10: 0.0030 - train_ndcg@20: 0.0034 - train_recall@10: 0.0059 - train_recall@20: 0.0075 - loss: 11.5477 - regularization_loss: 0.0000e+00 - total_loss: 11.5477WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  69/438 [===>..........................] - ETA: 34:12 - train_ndcg@10: 0.0031 - train_ndcg@20: 0.0035 - train_recall@10: 0.0060 - train_recall@20: 0.0077 - loss: 11.5373 - regularization_loss: 0.0000e+00 - total_loss: 11.5373WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  70/438 [===>..........................] - ETA: 34:07 - train_ndcg@10: 0.0031 - train_ndcg@20: 0.0036 - train_recall@10: 0.0060 - train_recall@20: 0.0077 - loss: 11.5284 - regularization_loss: 0.0000e+00 - total_loss: 11.5284WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  71/438 [===>..........................] - ETA: 34:03 - train_ndcg@10: 0.0032 - train_ndcg@20: 0.0037 - train_recall@10: 0.0061 - train_recall@20: 0.0079 - loss: 11.5167 - regularization_loss: 0.0000e+00 - total_loss: 11.5167WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  72/438 [===>..........................] - ETA: 34:00 - train_ndcg@10: 0.0033 - train_ndcg@20: 0.0037 - train_recall@10: 0.0061 - train_recall@20: 0.0079 - loss: 11.5066 - regularization_loss: 0.0000e+00 - total_loss: 11.5066WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  73/438 [====>.........................] - ETA: 33:51 - train_ndcg@10: 0.0034 - train_ndcg@20: 0.0039 - train_recall@10: 0.0063 - train_recall@20: 0.0082 - loss: 11.4919 - regularization_loss: 0.0000e+00 - total_loss: 11.4919WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  74/438 [====>.........................] - ETA: 33:45 - train_ndcg@10: 0.0035 - train_ndcg@20: 0.0040 - train_recall@10: 0.0065 - train_recall@20: 0.0086 - loss: 11.4781 - regularization_loss: 0.0000e+00 - total_loss: 11.4781WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  75/438 [====>.........................] - ETA: 33:39 - train_ndcg@10: 0.0036 - train_ndcg@20: 0.0041 - train_recall@10: 0.0066 - train_recall@20: 0.0087 - loss: 11.4662 - regularization_loss: 0.0000e+00 - total_loss: 11.4662WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  76/438 [====>.........................] - ETA: 33:32 - train_ndcg@10: 0.0036 - train_ndcg@20: 0.0042 - train_recall@10: 0.0067 - train_recall@20: 0.0089 - loss: 11.4536 - regularization_loss: 0.0000e+00 - total_loss: 11.4536WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#  77/438 [====>.........................] - ETA: 33:27 - train_ndcg@10: 0.0038 - train_ndcg@20: 0.0043 - train_recall@10: 0.0069 - train_recall@20: 0.0093 - loss: 11.4392 - regularization_loss: 0.0000e+00 - total_loss: 11.4392WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# ...
# 389/414 [===========================>..] - ETA: 2:12 - train_ndcg@10: 0.7373 - train_ndcg@20: 0.7405 - train_recall@10: 0.7532 - train_recall@20: 0.7659 - loss: 2.3966 - regularization_loss: 0.0000e+00 - total_loss: 2.3966WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 390/414 [===========================>..] - ETA: 2:07 - train_ndcg@10: 0.7373 - train_ndcg@20: 0.7405 - train_recall@10: 0.7532 - train_recall@20: 0.7659 - loss: 2.3967 - regularization_loss: 0.0000e+00 - total_loss: 2.3967WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 391/414 [===========================>..] - ETA: 2:02 - train_ndcg@10: 0.7374 - train_ndcg@20: 0.7405 - train_recall@10: 0.7533 - train_recall@20: 0.7660 - loss: 2.3959 - regularization_loss: 0.0000e+00 - total_loss: 2.3959WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 392/414 [===========================>..] - ETA: 1:56 - train_ndcg@10: 0.7374 - train_ndcg@20: 0.7406 - train_recall@10: 0.7534 - train_recall@20: 0.7660 - loss: 2.3956 - regularization_loss: 0.0000e+00 - total_loss: 2.3956WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 393/414 [===========================>..] - ETA: 1:51 - train_ndcg@10: 0.7374 - train_ndcg@20: 0.7406 - train_recall@10: 0.7534 - train_recall@20: 0.7660 - loss: 2.3955 - regularization_loss: 0.0000e+00 - total_loss: 2.3955WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 394/414 [===========================>..] - ETA: 1:46 - train_ndcg@10: 0.7374 - train_ndcg@20: 0.7406 - train_recall@10: 0.7534 - train_recall@20: 0.7660 - loss: 2.3952 - regularization_loss: 0.0000e+00 - total_loss: 2.3952WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 395/414 [===========================>..] - ETA: 1:40 - train_ndcg@10: 0.7375 - train_ndcg@20: 0.7407 - train_recall@10: 0.7535 - train_recall@20: 0.7661 - loss: 2.3944 - regularization_loss: 0.0000e+00 - total_loss: 2.3944WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 396/414 [===========================>..] - ETA: 1:35 - train_ndcg@10: 0.7376 - train_ndcg@20: 0.7408 - train_recall@10: 0.7535 - train_recall@20: 0.7662 - loss: 2.3936 - regularization_loss: 0.0000e+00 - total_loss: 2.3936WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 397/414 [===========================>..] - ETA: 1:30 - train_ndcg@10: 0.7377 - train_ndcg@20: 0.7409 - train_recall@10: 0.7536 - train_recall@20: 0.7663 - loss: 2.3927 - regularization_loss: 0.0000e+00 - total_loss: 2.3927WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 398/414 [===========================>..] - ETA: 1:24 - train_ndcg@10: 0.7377 - train_ndcg@20: 0.7409 - train_recall@10: 0.7537 - train_recall@20: 0.7663 - loss: 2.3924 - regularization_loss: 0.0000e+00 - total_loss: 2.3924WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 399/414 [===========================>..] - ETA: 1:19 - train_ndcg@10: 0.7378 - train_ndcg@20: 0.7409 - train_recall@10: 0.7537 - train_recall@20: 0.7664 - loss: 2.3920 - regularization_loss: 0.0000e+00 - total_loss: 2.3920WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 400/414 [===========================>..] - ETA: 1:14 - train_ndcg@10: 0.7378 - train_ndcg@20: 0.7410 - train_recall@10: 0.7538 - train_recall@20: 0.7664 - loss: 2.3917 - regularization_loss: 0.0000e+00 - total_loss: 2.3917WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 401/414 [============================>.] - ETA: 1:09 - train_ndcg@10: 0.7378 - train_ndcg@20: 0.7410 - train_recall@10: 0.7538 - train_recall@20: 0.7664 - loss: 2.3914 - regularization_loss: 0.0000e+00 - total_loss: 2.3914WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 402/414 [============================>.] - ETA: 1:03 - train_ndcg@10: 0.7379 - train_ndcg@20: 0.7410 - train_recall@10: 0.7538 - train_recall@20: 0.7665 - loss: 2.3909 - regularization_loss: 0.0000e+00 - total_loss: 2.3909WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 403/414 [============================>.] - ETA: 58s - train_ndcg@10: 0.7379 - train_ndcg@20: 0.7411 - train_recall@10: 0.7538 - train_recall@20: 0.7665 - loss: 2.3907 - regularization_loss: 0.0000e+00 - total_loss: 2.3907 WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 404/414 [============================>.] - ETA: 53s - train_ndcg@10: 0.7378 - train_ndcg@20: 0.7410 - train_recall@10: 0.7538 - train_recall@20: 0.7665 - loss: 2.3910 - regularization_loss: 0.0000e+00 - total_loss: 2.3910WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 405/414 [============================>.] - ETA: 47s - train_ndcg@10: 0.7379 - train_ndcg@20: 0.7411 - train_recall@10: 0.7539 - train_recall@20: 0.7666 - loss: 2.3903 - regularization_loss: 0.0000e+00 - total_loss: 2.3903WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 406/414 [============================>.] - ETA: 42s - train_ndcg@10: 0.7380 - train_ndcg@20: 0.7412 - train_recall@10: 0.7540 - train_recall@20: 0.7667 - loss: 2.3893 - regularization_loss: 0.0000e+00 - total_loss: 2.3893WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 407/414 [============================>.] - ETA: 37s - train_ndcg@10: 0.7381 - train_ndcg@20: 0.7413 - train_recall@10: 0.7540 - train_recall@20: 0.7668 - loss: 2.3887 - regularization_loss: 0.0000e+00 - total_loss: 2.3887WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 408/414 [============================>.] - ETA: 31s - train_ndcg@10: 0.7381 - train_ndcg@20: 0.7413 - train_recall@10: 0.7541 - train_recall@20: 0.7668 - loss: 2.3882 - regularization_loss: 0.0000e+00 - total_loss: 2.3882WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 409/414 [============================>.] - ETA: 26s - train_ndcg@10: 0.7382 - train_ndcg@20: 0.7414 - train_recall@10: 0.7541 - train_recall@20: 0.7669 - loss: 2.3879 - regularization_loss: 0.0000e+00 - total_loss: 2.3879WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 410/414 [============================>.] - ETA: 21s - train_ndcg@10: 0.7382 - train_ndcg@20: 0.7414 - train_recall@10: 0.7542 - train_recall@20: 0.7669 - loss: 2.3876 - regularization_loss: 0.0000e+00 - total_loss: 2.3876WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 411/414 [============================>.] - ETA: 15s - train_ndcg@10: 0.7382 - train_ndcg@20: 0.7414 - train_recall@10: 0.7542 - train_recall@20: 0.7670 - loss: 2.3871 - regularization_loss: 0.0000e+00 - total_loss: 2.3871WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 412/414 [============================>.] - ETA: 10s - train_ndcg@10: 0.7383 - train_ndcg@20: 0.7415 - train_recall@10: 0.7543 - train_recall@20: 0.7670 - loss: 2.3864 - regularization_loss: 0.0000e+00 - total_loss: 2.3864WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 413/414 [============================>.] - ETA: 5s - train_ndcg@10: 0.7384 - train_ndcg@20: 0.7416 - train_recall@10: 0.7543 - train_recall@20: 0.7671 - loss: 2.3856 - regularization_loss: 0.0000e+00 - total_loss: 2.3856 WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 414/414 [==============================] - 2194s 5s/step - train_ndcg@10: 0.7385 - train_ndcg@20: 0.7417 - train_recall@10: 0.7544 - train_recall@20: 0.7672 - loss: 2.3848 - regularization_loss: 0.0000e+00 - total_loss: 2.3848
# 379/379 [==============================] - 266s 702ms/step - eval_ndcg@10: 0.7474 - eval_ndcg@20: 0.7511 - eval_recall@10: 0.7640 - eval_recall@20: 0.7785 - loss: 2.2953 - regularization_loss: 0.0000e+00 - total_loss: 2.2953
# ********************
# Eval results for day 3 are:
#
# ********************
#
#  eval_ndcg@10 = 0.6198317408561707
#  eval_ndcg@20 = 0.6273594498634338
#  eval_recall@10 = 0.6307692527770996
#  eval_recall@20 = 0.6615384817123413
#  loss = 3.389691114425659
#  regularization_loss = 0
#  total_loss = 3.389691114425659
# CPU times: user 1h 26min 9s, sys: 23.5 s, total: 1h 26min 32s
# Wall time: 1h 28min 44s
