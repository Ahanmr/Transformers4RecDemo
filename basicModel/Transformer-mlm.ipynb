# %% [markdown]
# # Session-based Recs with Transformers4Rec: Transformer - Masked Language Model
#
# Followed a step by step tutorial:
# https://nvidia-merlin.github.io/Transformers4Rec/main/examples/tutorial/index.html

# %%
# !pip install tensorflow-metadata
# Out:
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.2.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 1.3 MB/s  eta 0:00:01
# Collecting absl-py<0.13,>=0.9
#   Downloading absl_py-0.12.0-py3-none-any.whl (129 kB)
#      |████████████████████████████████| 129 kB 46.3 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<4,>=3.13 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow-metadata) (3.19.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow-metadata) (1.53.0)
# Requirement already satisfied: six in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from absl-py<0.13,>=0.9->tensorflow-metadata) (1.15.0)
# ERROR: tensorflow-gpu 2.1.0 has requirement gast==0.2.2, but you'll have gast 0.4.0 which is incompatible.
# ERROR: tensorflow-gpu 2.1.0 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.5.2 which is incompatible.
# ERROR: tensorflow-gpu 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 2.6.0 which is incompatible.
# ERROR: tensorflow-gpu 2.1.0 has requirement tensorflow-estimator<2.2.0,>=2.1.0rc0, but you'll have tensorflow-estimator 2.6.0 which is incompatible.
# ERROR: autokeras 1.0.16.post1 has requirement tensorflow<2.6,>=2.3.0, but you'll have tensorflow 2.6.2 which is incompatible.
# Installing collected packages: absl-py, tensorflow-metadata
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.15.0
#     Uninstalling absl-py-0.15.0:
#       Successfully uninstalled absl-py-0.15.0
# Successfully installed absl-py-0.12.0 tensorflow-metadata-1.2.0

# %% [markdown]
# ## Imports

# %%
import os
import glob
import pandas as pd
import numpy as np

from transformers4rec import tf as tr
import tensorflow as tf
from transformers4rec.tf.ranking_metric import NDCGAt, RecallAt
from typing import Optional

# %% [markdown]
# ## Instantiates Schema object from schema file

# %%
# define the input file path
INPUT_DATA_DIR = os.environ.get("INPUT_DATA_DIR", '../data/')
# define the output file path
OUTPUT_DIR = os.environ.get("OUTPUT_DIR", "../data/sessions_by_day")
# features chosen to train on
chosen_features = ['product_id-list_seq']
from merlin_standard_lib import Schema
# define schema object to pass it to the TabularSeqeunceFeatures class
SCHEMA_PATH = os.path.join(INPUT_DATA_DIR, 'schema.pb')
schema = Schema().from_proto_text(SCHEMA_PATH)
schema = schema.select_by_name(chosen_features)

# %% [markdown]
# ## Define Input Block

# %% [markdown]
# use MLM as the training method

# %%
# Input
sequence_length, d_model = 20, 192
# Define input module to process tabular input-features and to prepare masked inputs
inputs = tr.TabularSequenceFeatures.from_schema(
    schema,
    max_sequence_length = sequence_length,
    d_output = d_model,
    masking = 'mlm'
)

# %% [markdown]
# ## Build Transformer Block

# %%
# define XLNetConfig class and set default parameters for HF XLNet config
transformer_config = tr.XLNetConfig.build(
    d_model = d_model, n_head=4, n_layer=2, total_seq_length=sequence_length
)

# define the model block including: inputs, masking, projection and transformer block.

body = tr.SequentialBlock(
    [inputs,
    tr.MLPBlock([192]),
    tr.TransformerBlock(transformer_config, masking=inputs.masking)]
)

# define the head for to the next item prediction task

head = tr.Head(
    body,
    tr.NextItemPredictionTask(
        weight_tying=True, 
        # hf_format=True, 
        metrics=[NDCGAt(top_ks=[10, 20], labels_onehot=True),RecallAt(top_ks=[10, 20], labels_onehot=True)],
        # loss = tf.keras.losses.CategoricalCrossentropy)
))
# head = tr.Head(
#     body,
#     tr.NextItemPredictionTask(
#         weight_tying=True, 
#         # hf_format=True, 
#         metrics=[NDCGAt_temp(top_ks=[10, 20], labels_onehot=False)]
#         # loss = tf.keras.losses.CategoricalCrossentropy)
# ))

# get the end-to-end Model class

model = tr.Model(head)

# %% [markdown]
# ## Build Datasets

# %%
def iterate_over_df(
    ### iterator function as input for the tensorflow generator `from_generator` function
    df: pd.DataFrame
):  
    df['empty_list'] = [[] for _ in range(len(df))]
    def caller():
        for _,j in df.iterrows():
            yield(j['product_id-list_seq']),j['empty_list']
    return caller

# %%
def ds_from_df(
    ### generate tensorflow object from dataframe
    df: pd.DataFrame
):
    output_shape_x = (
        tf.TensorShape([None,])
    )
    df = tf.data.Dataset.from_generator(
        iterate_over_df(df),
        output_types=((tf.int32),tf.int32),
        output_shapes = (output_shape_x, tf.TensorShape([None,]))
    )
    return df

# %%
def pad_dataset(
        ## pad dataset so all session sequence data have length 20
        df,
        batch_size: int,
):
        df = df.shuffle(5)
        df = df.padded_batch(batch_size, padded_shapes = (([20,]),[0,]), padding_values = ((0),0),drop_remainder=True)
        df = df.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

        return df

# %%
def data_to_dict(
    ### create a dictionary tensor dataframe as input into the model
    df_list: list,
    chosen_features: list
):
    df_dictionary = {}
    df_dictionary2 = {}
    if len(chosen_features) == 1:
        df_dictionary[chosen_features[0]] = df_list[0][0]
    else:
        for i in range(len(chosen_features)):
            df_dictionary[chosen_features[i]] = df_list[0][0][i]
        df_dictionary2['labels'] = df_list[0][-1]
    return (df_dictionary, df_dictionary2)

# %%
def get_dataset(
    ### function to call all other functions necessary to build the dataset
    ### to input into the model
    df,
    batch_size,
    df_len
):
    df = ds_from_df(df)
    df = pad_dataset(df,df_len)
    df = data_to_dict(list(df),chosen_features)
    ds = tf.data.Dataset.from_tensor_slices(df).batch(batch_size)
    steps = int(np.floor(df_len/batch_size))
    ds = ds.map(lambda X, y: (X, []))


    return ds, steps

# %% [markdown]
# ## Daily Fine-tuning: Training over a time window

# %% [markdown]
# ### Train the model

# %%
model.compile(optimizer='adam',run_eagerly=True)

# %%
train_batch_size = 256
eval_batch_size = 32

# %%
# %%time
# window
start_time_window_index = 1
final_time_window_index = 3
# Iterating over days of one week
for time_index in range(start_time_window_index, final_time_window_index):
    # Set data 
    time_index_train = time_index
    time_index_eval = time_index + 1
    train_paths = os.path.join(OUTPUT_DIR, f"{time_index_train}/train.parquet")
    eval_paths = os.path.join(OUTPUT_DIR, f"{time_index_eval}/valid.parquet")

    # Load data
    train_df = pd.read_parquet(train_paths)
    train_df = train_df[['product_id-list_seq']]
    eval_df = pd.read_parquet(eval_paths)
    eval_df = eval_df[['product_id-list_seq']]

    # find length of dataframes for argument into `get_dataset`
    train_len = len(train_df)
    eval_len = len(eval_df)

    # get datasets
    train_dataset, train_steps = get_dataset(train_df, train_batch_size,train_len)
    eval_dataset, eval_steps = get_dataset(eval_df, eval_batch_size,eval_len)
    
    # Train on day related to time_index 
    print('*'*20)
    print("Launch training for day %s are:" %time_index)
    print('*'*20 + '\n')
    losses = model.fit(train_dataset, epochs=1)
    model.reset_metrics()
    # Evaluate on the following day
    eval_metrics = model.evaluate(eval_dataset, return_dict=True)
    print('*'*20)
    print("Eval results for day %s are:\t" %time_index_eval)
    print('\n' + '*'*20 + '\n')
    for key in sorted(eval_metrics.keys()):
        print(" %s = %s" % (key, str(eval_metrics[key])))
# Out:
# ********************
# Launch training for day 1 are:
# ********************
# Projecting inputs of NextItemPredictionTask to'64' As weight tying requires the input dimension '192' to be equal to the item-id embedding dimension '64'
# WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   1/438 [..............................] - ETA: 3:15:27 - train_ndcg@10: 0.0000e+00 - train_ndcg@20: 0.0000e+00 - train_recall@10: 0.0000e+00 - train_recall@20: 0.0000e+00 - loss: 11.9448 - regularization_loss: 0.0000e+00 - total_loss: 11.9448WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   2/438 [..............................] - ETA: 16:08 - train_ndcg@10: 0.0000e+00 - train_ndcg@20: 0.0000e+00 - train_recall@10: 0.0000e+00 - train_recall@20: 0.0000e+00 - loss: 11.8289 - regularization_loss: 0.0000e+00 - total_loss: 11.8289  WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   3/438 [..............................] - ETA: 16:33 - train_ndcg@10: 2.3500e-04 - train_ndcg@20: 2.3500e-04 - train_recall@10: 7.8064e-04 - train_recall@20: 7.8064e-04 - loss: 11.7006 - regularization_loss: 0.0000e+00 - total_loss: 11.7006WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   4/438 [..............................] - ETA: 16:29 - train_ndcg@10: 1.7625e-04 - train_ndcg@20: 3.3447e-04 - train_recall@10: 5.8548e-04 - train_recall@20: 0.0012 - loss: 11.5913 - regularization_loss: 0.0000e+00 - total_loss: 11.5913    WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   5/438 [..............................] - ETA: 16:25 - train_ndcg@10: 2.7513e-04 - train_ndcg@20: 0.0012 - train_recall@10: 9.3242e-04 - train_recall@20: 0.0047 - loss: 11.4833 - regularization_loss: 0.0000e+00 - total_loss: 11.4833    WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   6/438 [..............................] - ETA: 16:15 - train_ndcg@10: 0.0020 - train_ndcg@20: 0.0029 - train_recall@10: 0.0049 - train_recall@20: 0.0085 - loss: 11.3734 - regularization_loss: 0.0000e+00 - total_loss: 11.3734        WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   7/438 [..............................] - ETA: 16:12 - train_ndcg@10: 0.0049 - train_ndcg@20: 0.0060 - train_recall@10: 0.0093 - train_recall@20: 0.0137 - loss: 11.2723 - regularization_loss: 0.0000e+00 - total_loss: 11.2723WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   8/438 [..............................] - ETA: 15:57 - train_ndcg@10: 0.0090 - train_ndcg@20: 0.0105 - train_recall@10: 0.0167 - train_recall@20: 0.0225 - loss: 11.1513 - regularization_loss: 0.0000e+00 - total_loss: 11.1513WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
ARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 397/414 [===========================>..] - ETA: 38s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0142 - regularization_loss: 0.0000e+00 - total_loss: 0.0142WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 398/414 [===========================>..] - ETA: 35s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0142 - regularization_loss: 0.0000e+00 - total_loss: 0.0142WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 399/414 [===========================>..] - ETA: 33s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0142 - regularization_loss: 0.0000e+00 - total_loss: 0.0142WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 400/414 [===========================>..] - ETA: 31s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0142 - regularization_loss: 0.0000e+00 - total_loss: 0.0142WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 401/414 [============================>.] - ETA: 29s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0141 - regularization_loss: 0.0000e+00 - total_loss: 0.0141WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 402/414 [============================>.] - ETA: 26s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0141 - regularization_loss: 0.0000e+00 - total_loss: 0.0141WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 403/414 [============================>.] - ETA: 24s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0141 - regularization_loss: 0.0000e+00 - total_loss: 0.0141WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 404/414 [============================>.] - ETA: 22s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0141 - regularization_loss: 0.0000e+00 - total_loss: 0.0141WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 405/414 [============================>.] - ETA: 20s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0141 - regularization_loss: 0.0000e+00 - total_loss: 0.0141WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 406/414 [============================>.] - ETA: 17s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0141 - regularization_loss: 0.0000e+00 - total_loss: 0.0141WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 407/414 [============================>.] - ETA: 15s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0140 - regularization_loss: 0.0000e+00 - total_loss: 0.0140WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 408/414 [============================>.] - ETA: 13s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0140 - regularization_loss: 0.0000e+00 - total_loss: 0.0140WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 409/414 [============================>.] - ETA: 11s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0140 - regularization_loss: 0.0000e+00 - total_loss: 0.0140WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 410/414 [============================>.] - ETA: 8s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0140 - regularization_loss: 0.0000e+00 - total_loss: 0.0140 WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 411/414 [============================>.] - ETA: 6s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0140 - regularization_loss: 0.0000e+00 - total_loss: 0.0140WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 412/414 [============================>.] - ETA: 4s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0140 - regularization_loss: 0.0000e+00 - total_loss: 0.0140WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 413/414 [============================>.] - ETA: 2s - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0139 - regularization_loss: 0.0000e+00 - total_loss: 0.0139WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 414/414 [==============================] - 928s 2s/step - train_ndcg@10: 0.9999 - train_ndcg@20: 0.9999 - train_recall@10: 1.0000 - train_recall@20: 1.0000 - loss: 0.0139 - regularization_loss: 0.0000e+00 - total_loss: 0.0139
# 379/379 [==============================] - 135s 358ms/step - eval_ndcg@10: 1.0000 - eval_ndcg@20: 1.0000 - eval_recall@10: 1.0000 - eval_recall@20: 1.0000 - loss: 0.0075 - regularization_loss: 0.0000e+00 - total_loss: 0.0075
# ********************
# Eval results for day 3 are:
#
# ********************
#
#  eval_ndcg@10 = 1.0
#  eval_ndcg@20 = 1.0
#  eval_recall@10 = 1.0
#  eval_recall@20 = 1.0
#  loss = 0.012882358394563198
#  regularization_loss = 0
#  total_loss = 0.012882358394563198
# CPU times: user 37min 26s, sys: 21.1 s, total: 37min 47s
# Wall time: 38min 46s
