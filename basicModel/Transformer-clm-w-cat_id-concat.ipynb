# %% [markdown]
# # Session-based Recs with Transformers4Rec: Transformer w/ Cateogry ID (Concat Aggregation)
#
# Followed a step by step tutorial:
# https://nvidia-merlin.github.io/Transformers4Rec/main/examples/tutorial/index.html

# %% [markdown]
# ## Imports

# %%
import os
import glob
import pandas as pd
import numpy as np

from transformers4rec import tf as tr
import tensorflow as tf
from transformers4rec.tf.ranking_metric import NDCGAt, RecallAt
from typing import Optional

# %% [markdown]
# ## Instantiates Schema object from schema file

# %%
# define the input file path
INPUT_DATA_DIR = os.environ.get("INPUT_DATA_DIR", '../data/')
# define the output file path
OUTPUT_DIR = os.environ.get("OUTPUT_DIR", "../data/sessions_by_day")
# features chosen to train on
chosen_features = ['product_id-list_seq','category_id-list_seq']
from merlin_standard_lib import Schema
# define schema object to pass it to the TabularSeqeunceFeatures class
SCHEMA_PATH = os.path.join(INPUT_DATA_DIR, 'schema_side_info.pb')
schema = Schema().from_proto_text(SCHEMA_PATH)
schema = schema.select_by_name(chosen_features)

# %% [markdown]
# ## Define Input Block

# %% [markdown]
# use MLM as the training method

# %%
# Input
sequence_length, d_model = 20, 192
# Define input module to process tabular input-features and to prepare masked inputs
inputs = tr.TabularSequenceFeatures.from_schema(
    schema,
    max_sequence_length = sequence_length,
    d_output = d_model,
    aggregation='concat',
    masking = 'clm'
)

# %% [markdown]
# ## Build Transformer Block

# %%
# define XLNetConfig class and set default parameters for HF XLNet config
transformer_config = tr.XLNetConfig.build(
    d_model = d_model, n_head=4, n_layer=2, total_seq_length=sequence_length
)

# define the model block including: inputs, masking, projection and transformer block.

body = tr.SequentialBlock(
    [inputs,
    tr.MLPBlock([192]),
    tr.TransformerBlock(transformer_config, masking=inputs.masking)]
)

# define the head for to the next item prediction task

head = tr.Head(
    body,
    tr.NextItemPredictionTask(
        weight_tying=True, 
        # hf_format=True, 
        metrics=[NDCGAt(top_ks=[10, 20], labels_onehot=True),RecallAt(top_ks=[10, 20], labels_onehot=True)],
))

# get the end-to-end Model class

model = tr.Model(head)

# %% [markdown]
# ## Build Datasets

# %%
def iterate_over_df(
    ### iterator function as input for the tensorflow generator `from_generator` function
    df: pd.DataFrame
):  
    df['empty_list'] = [[] for _ in range(len(df))]
    def caller():
        for _,j in df.iterrows():
            yield(j['product_id-list_seq'], j['category_id-list_seq']),j['empty_list']
    return caller

# %%
def ds_from_df(
    ### generate tensorflow object from dataframe
    df: pd.DataFrame
):
    output_shape_x = (
        tf.TensorShape([None,]),
        tf.TensorShape([None,])
    )
    df = tf.data.Dataset.from_generator(
        iterate_over_df(df),
        output_types=((tf.int32,tf.int32),tf.int32),
        output_shapes = (output_shape_x, tf.TensorShape([None,]))
    )
    return df

# %%
def pad_dataset(
        ## pad dataset so all session sequence data have length 20
        df,
        batch_size: int,
):
        df = df.shuffle(5)
        df = df.padded_batch(batch_size, padded_shapes = (([20,],[20,]),[0,]), padding_values = ((0,0),0),drop_remainder=True)
        df = df.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

        return df

# %%
def data_to_dict(
    ### create a dictionary tensor dataframe as input into the model
    df_list: list,
    chosen_features: list
):
    df_dictionary = {}
    df_dictionary2 = {}
    if len(chosen_features) == 1:
        df_dictionary[chosen_features[0]] = df_list[0][0]
    else:
        for i in range(len(chosen_features)):
            df_dictionary[chosen_features[i]] = df_list[0][0][i]
        df_dictionary2['labels'] = df_list[0][-1]
    return (df_dictionary, df_dictionary2)

# %%
def get_dataset(
    ### function to call all other functions necessary to build the dataset
    ### to input into the model
    df,
    batch_size,
    df_len
):
    df = ds_from_df(df)
    df = pad_dataset(df,df_len)
    df = data_to_dict(list(df),chosen_features)
    ds = tf.data.Dataset.from_tensor_slices(df).batch(batch_size)
    steps = int(np.floor(df_len/batch_size))
    ds = ds.map(lambda X, y: (X, []))


    return ds, steps

# %% [markdown]
# ## Daily Fine-tuning: Training over a time window

# %% [markdown]
# ### Train the model

# %%
model.compile(optimizer='adam',run_eagerly=True)

# %%
train_batch_size = 256
eval_batch_size = 32

# %%
# %%time
# window
start_time_window_index = 1
final_time_window_index = 3
# Iterating over days of one week
for time_index in range(start_time_window_index, final_time_window_index):
    # Set data 
    time_index_train = time_index
    time_index_eval = time_index + 1
    train_paths = os.path.join(OUTPUT_DIR, f"{time_index_train}/train.parquet")
    eval_paths = os.path.join(OUTPUT_DIR, f"{time_index_eval}/valid.parquet")

    # Load data
    train_df = pd.read_parquet(train_paths)
    train_df = train_df[['product_id-list_seq','category_id-list_seq']]
    eval_df = pd.read_parquet(eval_paths)
    eval_df = eval_df[['product_id-list_seq','category_id-list_seq']]

    # find length of dataframes for argument into `get_dataset`
    train_len = len(train_df)
    eval_len = len(eval_df)

    # get datasets
    train_dataset, train_steps = get_dataset(train_df, train_batch_size,train_len)
    eval_dataset, eval_steps = get_dataset(eval_df, eval_batch_size,eval_len)
    
    # Train on day related to time_index 
    print('*'*20)
    print("Launch training for day %s are:" %time_index)
    print('*'*20 + '\n')
    losses = model.fit(train_dataset, epochs=1)
    model.reset_metrics()
    # Evaluate on the following day
    eval_metrics = model.evaluate(eval_dataset, return_dict=True)
    print('*'*20)
    print("Eval results for day %s are:\t" %time_index_eval)
    print('\n' + '*'*20 + '\n')
    for key in sorted(eval_metrics.keys()):
        print(" %s = %s" % (key, str(eval_metrics[key])))
# Out:
# ********************
# Launch training for day 1 are:
# ********************
# Projecting inputs of NextItemPredictionTask to'64' As weight tying requires the input dimension '192' to be equal to the item-id embedding dimension '64'
# WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   1/438 [..............................] - ETA: 1:29:08 - train_ndcg@10: 0.0000e+00 - train_ndcg@20: 0.0000e+00 - train_recall@10: 0.0000e+00 - train_recall@20: 0.0000e+00 - loss: 11.9219 - regularization_loss: 0.0000e+00 - total_loss: 11.9219WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   2/438 [..............................] - ETA: 37:45 - train_ndcg@10: 0.0000e+00 - train_ndcg@20: 0.0000e+00 - train_recall@10: 0.0000e+00 - train_recall@20: 0.0000e+00 - loss: 11.8531 - regularization_loss: 0.0000e+00 - total_loss: 11.8531  WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   3/438 [..............................] - ETA: 39:10 - train_ndcg@10: 0.0000e+00 - train_ndcg@20: 0.0000e+00 - train_recall@10: 0.0000e+00 - train_recall@20: 0.0000e+00 - loss: 11.8081 - regularization_loss: 0.0000e+00 - total_loss: 11.8081WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#   4/438 [..............................] - ETA: 40:15 - train_ndcg@10: 0.0000e+00 - train_ndcg@20: 0.0000e+00 - train_recall@10: 0.0000e+00 - train_recall@20: 0.0000e+00 - loss: 11.7773 - regularization_loss: 0.0000e+00 - total_loss: 11.7773WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
#
ARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 405/414 [============================>.] - ETA: 45s - train_ndcg@10: 0.7294 - train_ndcg@20: 0.7329 - train_recall@10: 0.7479 - train_recall@20: 0.7618 - loss: 2.4790 - regularization_loss: 0.0000e+00 - total_loss: 2.4790WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 406/414 [============================>.] - ETA: 40s - train_ndcg@10: 0.7295 - train_ndcg@20: 0.7330 - train_recall@10: 0.7481 - train_recall@20: 0.7620 - loss: 2.4779 - regularization_loss: 0.0000e+00 - total_loss: 2.4779WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 407/414 [============================>.] - ETA: 35s - train_ndcg@10: 0.7295 - train_ndcg@20: 0.7330 - train_recall@10: 0.7481 - train_recall@20: 0.7620 - loss: 2.4772 - regularization_loss: 0.0000e+00 - total_loss: 2.4772WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 408/414 [============================>.] - ETA: 30s - train_ndcg@10: 0.7296 - train_ndcg@20: 0.7331 - train_recall@10: 0.7482 - train_recall@20: 0.7621 - loss: 2.4767 - regularization_loss: 0.0000e+00 - total_loss: 2.4767WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 409/414 [============================>.] - ETA: 25s - train_ndcg@10: 0.7296 - train_ndcg@20: 0.7331 - train_recall@10: 0.7482 - train_recall@20: 0.7621 - loss: 2.4763 - regularization_loss: 0.0000e+00 - total_loss: 2.4763WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 410/414 [============================>.] - ETA: 20s - train_ndcg@10: 0.7297 - train_ndcg@20: 0.7332 - train_recall@10: 0.7482 - train_recall@20: 0.7622 - loss: 2.4760 - regularization_loss: 0.0000e+00 - total_loss: 2.4760WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 411/414 [============================>.] - ETA: 15s - train_ndcg@10: 0.7297 - train_ndcg@20: 0.7332 - train_recall@10: 0.7483 - train_recall@20: 0.7622 - loss: 2.4755 - regularization_loss: 0.0000e+00 - total_loss: 2.4755WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 412/414 [============================>.] - ETA: 10s - train_ndcg@10: 0.7298 - train_ndcg@20: 0.7333 - train_recall@10: 0.7483 - train_recall@20: 0.7623 - loss: 2.4749 - regularization_loss: 0.0000e+00 - total_loss: 2.4749WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 413/414 [============================>.] - ETA: 5s - train_ndcg@10: 0.7298 - train_ndcg@20: 0.7333 - train_recall@10: 0.7484 - train_recall@20: 0.7624 - loss: 2.4740 - regularization_loss: 0.0000e+00 - total_loss: 2.4740 WARNING:tensorflow:Gradients do not exist for variables ['transformer_block/transformer/mask_emb:0', 'transformer_block/transformer/layer_._0/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._0/rel_attn/seg_embed:0', 'transformer_block/transformer/layer_._1/rel_attn/r_s_bias:0', 'transformer_block/transformer/layer_._1/rel_attn/seg_embed:0'] when minimizing the loss.
# 414/414 [==============================] - 2078s 5s/step - train_ndcg@10: 0.7299 - train_ndcg@20: 0.7334 - train_recall@10: 0.7485 - train_recall@20: 0.7625 - loss: 2.4732 - regularization_loss: 0.0000e+00 - total_loss: 2.4732
# 379/379 [==============================] - 258s 681ms/step - eval_ndcg@10: 0.7368 - eval_ndcg@20: 0.7409 - eval_recall@10: 0.7568 - eval_recall@20: 0.7729 - loss: 2.4049 - regularization_loss: 0.0000e+00 - total_loss: 2.4049
# ********************
# Eval results for day 3 are:
#
# ********************
#
#  eval_ndcg@10 = 0.608638346195221
#  eval_ndcg@20 = 0.608638346195221
#  eval_recall@10 = 0.6206896305084229
#  eval_recall@20 = 0.6206896305084229
#  loss = 3.8045849800109863
#  regularization_loss = 0
#  total_loss = 3.8045849800109863
# CPU times: user 1h 21min 56s, sys: 23.6 s, total: 1h 22min 20s
# Wall time: 1h 24min 28s
